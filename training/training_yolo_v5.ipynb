# %%
# !pip3 install ultralytics 
# !pip3 install roboflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ultralytics in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (8.3.248)
# Requirement already satisfied: numpy>=1.23.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from ultralytics) (2.0.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from ultralytics) (3.9.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from ultralytics) (2.8.0)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from ultralytics) (0.23.0)
# Requirement already satisfied: psutil>=5.8.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from ultralytics) (7.1.0)
# Requirement already satisfied: polars>=0.20.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from ultralytics) (1.36.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics) (3.21.0)
# Requirement already satisfied: polars-runtime-32==1.36.1 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from polars>=0.20.0->ultralytics) (1.36.1)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from torch>=1.8.0->ultralytics) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: roboflow in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (1.2.11)
# Requirement already satisfied: certifi in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from roboflow) (2025.8.3)
# Requirement already satisfied: idna==3.7 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from roboflow) (1.4.7)
# Requirement already satisfied: matplotlib in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from roboflow) (3.9.4)
# Requirement already satisfied: numpy>=1.18.5 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from roboflow) (2.0.1)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from roboflow) (11.1.0)
# Requirement already satisfied: pi-heif<2 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from roboflow) (1.1.1)
# Requirement already satisfied: pillow-avif-plugin<2 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from roboflow) (1.2.1)
# Requirement already satisfied: requests in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from roboflow) (2.32.5)
# Requirement already satisfied: six in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from roboflow) (1.15.0)
# Requirement already satisfied: urllib3>=1.26.6 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests-toolbelt in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from matplotlib->roboflow) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from matplotlib->roboflow) (4.57.0)
# Requirement already satisfied: packaging>=20.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from matplotlib->roboflow) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib->roboflow) (3.21.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/dinhductri/Library/Python/3.9/lib/python/site-packages (from requests->roboflow) (3.4.3)

# %% [markdown]
# # Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="2cAgsVH4fUkQfElmtFS2")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(2)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-2 to yolov5pytorch:: 100%|██████████| 116758/116758 [00:04<00:00, 24889.02it/s]
# Extracting Dataset Version Zip to football-players-detection-2 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 6056.87it/s]

# %%
dataset.location
# Out:
# '/Users/dinhductri/Documents/Personal Projects/Football-Analysis/training/football-players-detection-2'

# %%
import shutil

shutil.move("football-players-detection-2/train", 
            "football-players-detection-2/football-players-detection-2/train")
            
shutil.move("football-players-detection-2/valid", 
            "football-players-detection-2/football-players-detection-2/valid")

shutil.move("football-players-detection-2/test", 
            "football-players-detection-2/football-players-detection-2/test")
# Out:
# 'football-players-detection-2/football-players-detection-2/test'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5s.pt data={dataset.location}/data.yaml epochs=50 imgsz=640 batch=32
# Out:
# Traceback (most recent call last):
#   File "/Users/dinhductri/Library/Python/3.9/bin/yolo", line 7, in <module>
#     sys.exit(entrypoint())
#   File "/Users/dinhductri/Library/Python/3.9/lib/python/site-packages/ultralytics/cfg/__init__.py", line 906, in entrypoint
#     check_dict_alignment(full_args_dict, {a: ""})
#   File "/Users/dinhductri/Library/Python/3.9/lib/python/site-packages/ultralytics/cfg/__init__.py", line 505, in check_dict_alignment
#     raise SyntaxError(string + CLI_HELP_MSG) from e
# SyntaxError: 'Projects/Football-Analysis/training/football-players-detection-2/data.yaml' is not a valid YOLO argument.
#
#     Arguments received: ['yolo', 'task=detect', 'mode=train', 'model=yolov5x.pt', 'data=/Users/dinhductri/Documents/Personal', 'Projects/Football-Analysis/training/football-players-detection-2/data.yaml', 'epochs=100', 'imgsz=640']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ['pose', 'segment', 'detect', 'classify', 'obb']
#                 MODE (required) is one of ['val', 'export', 'track', 'train', 'predict', 'benchmark']
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
#                     See all ARGS at https://docs.ultralytics.com/usage/cfg or with 'yolo cfg'
#
#     1. Train a detection model for 10 epochs with an initial learning_rate of 0.01
#         yolo train data=coco8.yaml model=yolo11n.pt epochs=10 lr0=0.01
#
#     2. Predict a YouTube video using a pretrained segmentation model at image size 320:
#         yolo predict model=yolo11n-seg.pt source='https://youtu.be/LNwODJXcvt4' imgsz=320
#
#     3. Validate a pretrained detection model at batch-size 1 and image size 640:
#         yolo val model=yolo11n.pt data=coco8.yaml batch=1 imgsz=640
#
#     4. Export a YOLO11n classification model to ONNX format at image size 224 by 128 (no TASK required)
#         yolo export model=yolo11n-cls.pt format=onnx imgsz=224,128
#
#     5. Ultralytics solutions usage
#         yolo solutions count or any of ['crop', 'blur', 'workout', 'heatmap', 'isegment', 'visioneye', 'speed', 'queue', 'analytics', 'inference', 'trackzone'] source="path/to/video.mp4"
#
#     6. Run special commands:
#         yolo help
#         yolo checks
#         yolo version
#         yolo settings
#         yolo copy-cfg
#         yolo cfg
#         yolo solutions help
#
#     Docs: https://docs.ultralytics.com
#     Solutions: https://docs.ultralytics.com/solutions/
#     Community: https://community.ultralytics.com
#     GitHub: https://github.com/ultralytics/ultralytics
